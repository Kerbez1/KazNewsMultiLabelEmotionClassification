# %%
import torch
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertForSequenceClassification, AdamW
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score, f1_score, hamming_loss
import pandas as pd
import numpy as np
import json
import time

# Data loading
df = pd.read_csv('emotions_normalized_dataset.csv', header=None, names=['text', 'emotions'], skiprows=1)

def normalize_emotions(emotion_str):
    if pd.isna(emotion_str) or emotion_str.strip() == "":
        return []
    emotion_str = emotion_str.strip('"').replace("'", '"')
    return json.loads(emotion_str)

df['emotions'] = df['emotions'].apply(normalize_emotions)

# Select the primary emotion as the first one in the list with the highest frequency across the dataset

primary_emotions = ['қайғы', 'қуаныш', 'уайым', 'мақтаныш', 'нейтрал', 'таңқалу']
df['primary_emotion'] = df['emotions'].apply(lambda x: [x[0]] if x else ['нейтрал'])
df['secondary_emotions'] = df['emotions'].apply(lambda x: x[1:] if len(x) > 1 else [])

mlb_primary = MultiLabelBinarizer()
mlb_secondary = MultiLabelBinarizer()
df_primary = pd.DataFrame(mlb_primary.fit_transform(df['primary_emotion']), columns=mlb_primary.classes_)
df_secondary = pd.DataFrame(mlb_secondary.fit_transform(df['secondary_emotions']), columns=mlb_secondary.classes_)
df = pd.concat([df['text'], df_primary, df_secondary], axis=1)

train_texts, val_texts, train_labels_primary, val_labels_primary = train_test_split(
    df['text'], df_primary.values, test_size=0.2, random_state=42
)
train_labels_secondary, val_labels_secondary = train_test_split(
    df_secondary.values, test_size=0.2, random_state=42
)

#  Class Dataset
class EmotionDataset(Dataset):
    def __init__(self, texts, labels_primary, labels_secondary, tokenizer, max_len):
        self.texts = texts
        self.labels_primary = labels_primary
        self.labels_secondary = labels_secondary
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts.iloc[idx]
        labels_primary = torch.tensor(self.labels_primary[idx], dtype=torch.float32)
        labels_secondary = torch.tensor(self.labels_secondary[idx], dtype=torch.float32)
        encoding = self.tokenizer(text, max_length=self.max_len, 
                                  padding='max_length', 
                                  truncation=True, 
                                  return_tensors='pt')
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels_primary': labels_primary,
            'labels_secondary': labels_secondary
        }

# tokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

train_dataset = EmotionDataset(train_texts, train_labels_primary, train_labels_secondary, tokenizer, max_len=128)
val_dataset = EmotionDataset(val_texts, val_labels_primary, val_labels_secondary, tokenizer, max_len=128)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)


model_primary = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased', 
                                                              num_labels=len(mlb_primary.classes_))
model_secondary = BertForSequenceClassification.from_pretrained('bert-base-multilingual-cased',
                                                                num_labels=len(mlb_secondary.classes_))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_primary.to(device)
model_secondary.to(device)

optimizer_primary = AdamW(model_primary.parameters(), lr=2e-5)
optimizer_secondary = AdamW(model_secondary.parameters(), lr=2e-5)

# Model training
def train_model(model, train_loader, val_loader, optimizer, device, epochs=10, is_primary=True):
    for epoch in range(epochs):
        start_time = time.time()
        model.train()
        train_loss, train_correct, total_train = 0, 0, 0
        
        for batch in train_loader:
            optimizer.zero_grad()
            input_ids, attention_mask = batch['input_ids'].to(device), batch['attention_mask'].to(device)
            labels = batch['labels_primary' if is_primary else 'labels_secondary'].to(device)
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            predictions = (torch.sigmoid(outputs.logits) > 0.5).float()
            train_correct += torch.sum(predictions == labels).item()
            total_train += labels.numel()
        
        train_acc = train_correct / total_train
        val_loss, val_acc = evaluate_model(model, val_loader, device, is_primary)
        epoch_time = time.time() - start_time
        print(f"Эпоха {epoch + 1}/{epochs}:\n  Train Loss: {train_loss / len(train_loader):.4f},
        Val Loss: {val_loss:.4f}\n  Train Accuracy: {train_acc:.4f}, 
        Val Accuracy: {val_acc:.4f}\n  Эпоха уақыты: {epoch_time:.2f} сек")

# Evaluation function
def evaluate_model(model, val_loader, device, is_primary=True):
    model.eval()
    val_loss, correct, total = 0, 0, 0
    with torch.no_grad():
        for batch in val_loader:
            input_ids, attention_mask = batch['input_ids'].to(device), batch['attention_mask'].to(device)
            labels = batch['labels_primary' if is_primary else 'labels_secondary'].to(device)
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            val_loss += outputs.loss.item()
            predictions = (torch.sigmoid(outputs.logits) > 0.5).float()
            correct += torch.sum(predictions == labels).item()
            total += labels.numel()
    return val_loss / len(val_loader), correct / total

# Start training (10 epochs for each classifier)
train_model(model_primary, train_loader, val_loader, optimizer_primary, device, epochs=10, is_primary=True)
train_model(model_secondary, train_loader, val_loader, optimizer_secondary, device, epochs=10, is_primary=False)

# Output predicted sentences
print("Predictions:")
for i in range(10):
    print(f"Text: {val_texts.iloc[i]}")
    print(f"Predicted primary emotion: {mlb_primary.inverse_transform(np.array([val_labels_primary[i]]))}")
    print(f"Predicted secondary emotion: {mlb_secondary.inverse_transform(np.array([val_labels_secondary[i]]))}")
    print("-" * 50)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Эпоха 1/10:
#   Train Loss: 0.5225, Val Loss: 0.4444
#   Train Accuracy: 0.7894, Val Accuracy: 0.8333
#   Время эпохи: 353.44 сек
# Эпоха 2/10:
#   Train Loss: 0.4374, Val Loss: 0.4170
#   Train Accuracy: 0.8333, Val Accuracy: 0.8333
#   Время эпохи: 302.57 сек
# Эпоха 3/10:
#   Train Loss: 0.4069, Val Loss: 0.3805
#   Train Accuracy: 0.8376, Val Accuracy: 0.8529
#   Время эпохи: 301.23 сек
# Эпоха 4/10:
#   Train Loss: 0.3813, Val Loss: 0.3788
#   Train Accuracy: 0.8486, Val Accuracy: 0.8490
#   Время эпохи: 313.45 сек
# Эпоха 5/10:
#   Train Loss: 0.3560, Val Loss: 0.3548
#   Train Accuracy: 0.8594, Val Accuracy: 0.8490
#   Время эпохи: 304.31 сек
# Эпоха 6/10:
#   Train Loss: 0.3123, Val Loss: 0.3944
#   Train Accuracy: 0.8786, Val Accuracy: 0.8503
#   Время эпохи: 301.03 сек
# Эпоха 7/10:
#   Train Loss: 0.2927, Val Loss: 0.3516
#   Train Accuracy: 0.8870, Val Accuracy: 0.8490
#   Время эпохи: 305.17 сек
# Эпоха 8/10:
#   Train Loss: 0.2575, Val Loss: 0.3681
#   Train Accuracy: 0.9098, Val Accuracy: 0.8320
#   Время эпохи: 300.86 сек
# Эпоха 9/10:
#   Train Loss: 0.2176, Val Loss: 0.4081
#   Train Accuracy: 0.9225, Val Accuracy: 0.8398
#   Время эпохи: 301.70 сек
# Эпоха 10/10:
#   Train Loss: 0.1837, Val Loss: 0.4037
#   Train Accuracy: 0.9456, Val Accuracy: 0.8385
#   Время эпохи: 301.20 сек
# Эпоха 1/10:
#   Train Loss: 0.4910, Val Loss: 0.4027
#   Train Accuracy: 0.8262, Val Accuracy: 0.8529
#   Время эпохи: 303.32 сек
# Эпоха 2/10:
#   Train Loss: 0.3772, Val Loss: 0.3789
#   Train Accuracy: 0.8597, Val Accuracy: 0.8529
#   Время эпохи: 302.38 сек
# Эпоха 3/10:
#   Train Loss: 0.3580, Val Loss: 0.3812
#   Train Accuracy: 0.8590, Val Accuracy: 0.8529
#   Время эпохи: 301.42 сек
# Эпоха 4/10:
#   Train Loss: 0.3449, Val Loss: 0.3770
#   Train Accuracy: 0.8604, Val Accuracy: 0.8607
#   Время эпохи: 301.26 сек
# Эпоха 5/10:
#   Train Loss: 0.3293, Val Loss: 0.3857
#   Train Accuracy: 0.8675, Val Accuracy: 0.8542
#   Время эпохи: 301.73 сек
# Эпоха 6/10:
#   Train Loss: 0.3064, Val Loss: 0.3863
#   Train Accuracy: 0.8809, Val Accuracy: 0.8581
#   Время эпохи: 300.83 сек
# Эпоха 7/10:
#   Train Loss: 0.2829, Val Loss: 0.3913
#   Train Accuracy: 0.8919, Val Accuracy: 0.8516
#   Время эпохи: 302.23 сек
# Эпоха 8/10:
#   Train Loss: 0.2616, Val Loss: 0.4126
#   Train Accuracy: 0.8981, Val Accuracy: 0.8438
#   Время эпохи: 300.95 сек
# Эпоха 9/10:
#   Train Loss: 0.2390, Val Loss: 0.3958
#   Train Accuracy: 0.9036, Val Accuracy: 0.8438
#   Время эпохи: 302.04 сек
# Эпоха 10/10:
#   Train Loss: 0.2128, Val Loss: 0.3883
#   Train Accuracy: 0.9115, Val Accuracy: 0.8411
#   Время эпохи: 301.90 сек
# Предсказания:
# Текст: алтын медаль алғым келген назым қызайбай жеңілісінен кейін көзіне жас алды назым қызайбай париж олимпиадасы аясында өткен бокс бәсекесінің жартылай финалында жеңіліс тауып қола жүлдегер атанғаннан кейін сұқбат берді бұл туралы kaznurkz хабарлайды тақырып бойынша жаңа жарияланым тарихтағы алғашқы жүкті жүлдегер жастағы спортшы жүктілігінің жетінші айында паралимпиадада қола жеңіп алды қыркүйек назым қызайбай хабар теларнасына берген сұқбатында жартылай финалдық бәсекеде жеңіс үшін барын салғанын айтты ұтуға барымды салдым бірақ қытай қызы барын салды қатты ұрамын деп арасында қатып қалдым барлық қарсылас бірдей қатты ұтқым келді алдап кетіп істейін деп едім әттегенай дейтін тұстарым бар алтын медаль алғым келген енді не болса да қолаға шүкір етеміз деді назым қызайбай айта кетейік назым қызайбай жартылай финалда қытай спортшысы ву юмен кездесті нәтижесінде назым қызайбай бұл жекпежекте есебімен жеңіліс тауып париж олимпиадасының қола жүлдегері атанды сондайақ тағы бір қазақстандық боксшы нұрбек оралбай кг дейінгі салмақ дәрежесінде украиналық александр хижнякпен финалда кездеседі жекпежек тамыздан тамызға қараған түні сағат де өтеді xxxiii жазғы олимпиада ойындары назым қызайбай олимпиада ойындарының қола жүлдегері атанды тамыз нора джеруто париж олимпиадасының жүлдесін еншілей алмады тамыз тақырып бойынша
# Предсказанная основная эмоция: [('мақтаныш',)]
# Предсказанные дополнительные эмоции: [('қуаныш',)]
# --------------------------------------------------
# Текст: жылыту маусымына дайындық кезеңінде олқылық жібергені үшін саран әкімі қызметінен босатылды қарағанды облысына қарасты саран қаласының әкімі еркін баулықов қалада жылу беру маусымының басталуында олқылық жібергені үшін қызметінен босатылды қала басшысы қызметін уақытша мақсат қайрешов атқаратын болды бұл туралы облыстық әкімдікке сілтеме жасаған kaznurkz хабарлайды қарағанды облысы әкімінің өкімімен саран қаласының әкімі еркін баулықов қалада жылу беру маусымының басталуында олқылық жібергені үшін ат
лық мәнжайы мен себептерін объективті зерттеуге бағытталған барлық қажетті тергеу әрекеттері жүргізіліп жатыр деп хабарлады облыстық полиция өкілдері айта кетейік бұған дейін алматыда мегаполис тұрғыны ермек жақыпжановтың бір күн бұрын жоғалып кеткені хабарланған болатын еріктілердің айтуынша ер адам таңертең ерте үйден көлігімен шығып кеткен полицейлер дерек бойынша қылмыстық іс қозғаған болатын
# Предсказанная основная эмоция: [('қайғы',)]
# Предсказанные дополнительные эмоции: [()]
# --------------------------------------------------
# Текст: қарағандыда құрылыс алаңында жұмысшы мерт болды қарағандыда құрылыс алаңында жұмыс істеп жүрген екі адам биіктен құлап кетті бірі оқиға орнында мерт болса екіншісі ауыр халде жансақтау бөлімінде жатыр деп хабарлайды kтк арнасы телеарна мәліметінше құрылысы жүріп жатқан ғимаратқа жұмысшылар лифт орнатуға келген екі адам темір тросқа бекітілген құрылғыға отырып жұмыс істеп жатқан осы кезде ол үзіліп кетіп екі жұмысшы төменге құлдилаған бірақ олардың нақты қай қабаттан құлағаны белгісіз оны енді сараптама анықтайды құрылыс нысанында тексеріс басталды адам өлімі бойынша қылмыстық іс те қозғалған әзірге тексеріс жүріп жатқанда құрылыс тоқтап тұр сараптамалар тағайындалады құрылғының өзі жоғарыға дұрыс бекітілмеді ме әлде бір жерінен үзіліп кетті ме оны анықтауға тиіс бұл біздің нысандарда лифт орнатып жүрген тәжірибелі маманы бар компания бәрін тексеріс анықтауға тиіс деді құрылыс компаниясының өкілі айдар алданыш дереккөз ктк
# Предсказанная основная эмоция: [('қайғы',)]
# Предсказанные дополнительные эмоции: [('таңқалу', 'уайым')]
# --------------------------------------------------
# Текст: жылғы қазан криптовалюталардың долларға шаққандағы бағамы binance блокчейнэкожүйесінің ақпаратына сәйкес криптовалюта нарығындағы жылғы қазан күнгі жағдай мынадай биткоиннің долларға шаққандағы бағамы өткен тәулік ішінде ға өсті бүгін актив төңірегінде саудаланады tronix криптовалютасы бүгін кешегі күнмен салыстырғанда ға өсті trx бағамы жылғы қазан күні ды құрап отыр ethereumнің долларға шаққандағы бағамы ға көтерілді аталған криптовалютаның құны бүгінде ды құрап отыр decentraland криптовалютасы тәулік ішінде ға қымбаттады қазіргі уақытта актив деңгейінде саудаланып жатыр true usd тәулік ішінде ға төмендеді tusd бағамы жылғы қазан күні ды құрап отыр litecoin криптовалютасы ға нығая түсті актив деңгейінде саудаланып жатыр ethereum classic бағасы бүгінде ға өсті криптовалютаның өзекті құны ripple өткен күнмен салыстырғанда ға қымбаттады криптовалютаның бүгінгі құны dogecoin кешегі күнмен салыстырғанда ға өсті қазіргі уақытта актив деңгейінде саудаланып жатыр материал binance криптовалюталық биржасының деректері негізінде әзірленген бағамдарға қатысты ақпарат мақала жарияланған сәтте өзекті
# Предсказанная основная эмоция: [('таңқалу',)]
# Предсказанные дополнительные эмоции: [('қуаныш',)]
# --------------------------------------------------
# Текст: танымал адвокат жанна оразбақова ерен еңбегі үшін медалімен марапатталды жылға сотталған қуандық бишімбаевтың ісінде жәбірленуші тараптың адвокаты болған жанна оразбақова ерен еңбегі үшін медалімен марапатталды бұл туралы kaznurkz хабарлайды құқыққорғаушы бұл жаңалықты instagram желісіндегі парақшасында жариялады бәріңізге сәлем жақсы жаңалықты бөліскім келіп отыр қазақстан республикасының тәуелсіздік күніне орай президенттің қазандағы жарлығы бойынша мені ерен еңбегі үшін мемлекеттік медальімен марапаттады бірақ мен елде болмауыма байланысты оны тек бүгін алдым деді жанна оразбақова еске салсақ бұған дейін қуандық бишімбаевтың ісін қараған судья айжан көлбаева ведомстволық наградамен марапатталған болатын
# Предсказанная основная эмоция: [('қуаныш',)]
# Предсказанные дополнительные эмоции: [('таңқалу',)]
# --------------------------------------------------
# Текст: жеке бақылауымда әкім екібастұз жэодағы жағдайға тоқталды екібастұз қаласының әкімі аян бейсекин қаланы жылумен қамту жүйесі жылу электр орталығындағы қазандықтарда жүргізіліп жатқан жөндеу жұмыстары туралы айтты бұл туралы kaznurkz әкімнің instagram дағы парақшасына сілтеме жасап хабарлайды қала басшысы instagram желісіндегі парақшасында бұған дейін бекітілген жоспар бойынша ектібастұз жэода жеті қазандық қажетті жөндеуден өткенін оның төртеуі жұмыс істеп тұрғанын үшеуі резервте тұрғанын хабарлады тағы бір қазандықты жөндеу жоспар бойынша қазанда аяқталады қалған екі қазандықтағы жөндеу жұмыстары тиісінше қараша және желтоқсан айларында бітеді бекітілген құрылысмонтаж жұмыстарының кестелерінен кешігулер жоқ деді аян бейсекин биыл күл шығару технологиясында басты рөл атқаратын тазартылған су құбыры да салынды құбыр тартылды қысымды сынау жұмыстары жүргізілді екі сорғыда монтаждау жұмыстары аяқталды сорғы жабдықтарын іске қосу жұмыстары жүргізілуде алдағы күндері желі пайдалануға беріледі сонымен қатар процестің осы бөлігінде жылыту маусымының қаупін азайту үшін тағы екі сорғы орнатылады екібастұз қаласының әкімі қалалық су арнасы мекемесінің басшысынан қаланы ыстық сумен қамтамасыз ету және орталық жылу пункттерін жаңғыртудың перспективалық жоспарлары туралы тыңдады жылыту маусымы қалыпты режимде жұмыс істеп тұр қазіргі жағдай мен ұзақ мерзімді жаңғырту жоспарлары павлодар облысы әкімінің жұмыс бақылауында және менің жеке бақылауымда деді аян бейсекин бұған дейін павлодар облысының әкімі асайын байханов екібастұзға жұмыс сапарымен барып электр стансасындағы турбиналар мен қазандықтардың жөндеу жұмыстарын тексерді сондайақ тазартылған су құбырының құрылысының барысымен танысқан еді
# Предсказанная основная эмоция: [('нейтрал',)]
# Предсказанные дополнительные эмоции: [('уайым',)]
# --------------------------------------------------

# %%
# Saving the models
model_primary.save_pretrained("model_primary")
model_secondary.save_pretrained("model_secondary")
tokenizer.save_pretrained("tokenizer")

print("Модели успешно сохранены!")
# Out:
# Модели успешно сохранены!

# %%
from transformers import BertForSequenceClassification, BertTokenizer

# Указываем полный путь к локальной папке с моделью
model_primary = BertForSequenceClassification.from_pretrained(r"C:\Users\asus\Дипломдык жумыс\модель оқыту\model_primary")
model_secondary = BertForSequenceClassification.from_pretrained(r"C:\Users\asus\Дипломдык жумыс\модель оқыту\model_secondary")

# Если токенизатор нужен
tokenizer = BertTokenizer.from_pretrained(r"C:\Users\asus\Дипломдык жумыс\модель оқыту\tokenizer")

print("Модели успешно загружены!")
# Out:
# Модели успешно загружены!
